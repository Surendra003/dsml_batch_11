# %%
import math
def student_result():
  i=0
  students = {}
  for student_detail in range(2):
    i+=1
    name = input(f"Enter {i} Student name: ")
    marks = float(input(f"Enter {i} Student Marks: "))
    student_dictionary = {
                          "Name":name,
                           "Marks":marks
                         }
    if 80<=marks<=100:
      grade = "A"
    elif 60<=marks<80:
      grade = "B"
    elif 40<=marks<60:
      grade = "C"
    elif marks<=40:
      grade = "F"
    else:
      grade = "Invalid Number"
    students[name] = {
                               "Marks":marks,
                                 "Grade":grade
                             }

  print(f"Dictionary of students are:{students}")
  highest = max(students, key=lambda name: students[name]["Marks"])
  print(f"Highest marks obtained by {highest} with marks: {students[highest]["Marks"]} and grade: {students[highest]["Grade"]}")
  lowest = min(students, key=lambda name: students[name]["Marks"])
  print(f"Lowest marks obtained by {lowest} with marks: {students[lowest]["Marks"]} and grade: {students[lowest]["Grade"]}")
  print(f"Average of marks: {marks/5}")
student_result()
# Out:
# Enter 1 Student name: surendra
# Enter 1 Student Marks: 67
# Enter 2 Student name: hari
# Enter 2 Student Marks: 98
# Dictionary of students are:{'surendra': {'Marks': 67.0, 'Grade': 'B'}, 'hari': {'Marks': 98.0, 'Grade': 'A'}}
# Highest marks obtained by hari with marks: 98.0 and grade: A
# Lowest marks obtained by surendra with marks: 67.0 and grade: B
# Average of marks: 19.6

# %% [markdown]
# **2.Smart Shopping cart System**
#
# Create a user defined function called shopping_cart() that:
#
# 1.Allows the user to enter 5 product prise
#
# 2.Stores the price in a list
#
# 3.uses the loop to calculate the total bill
#
# 4.applies discount using conditional statements:
#
# -Total>=5000 ->15% discount
#
# -Total>=3000 ->10% discount
#
# -Total>=1000 ->5% discount
#
# -Otherwise -> No discount
#
# 5.Display
#
# -Product list
#
# -Total Amount
#
# -Discount Amount
#
# -Final Payable amount

# %%
def shopping_cart():
  lst = []
  i=0
  sum=0
  for price in range(5):
    i+=1
    product_price = float(input(f"Enter a {i} product price: Npr."))
    lst.append(product_price)
    print(lst)
    sum+=product_price
  print("Summary your product price list is:",lst)
  print(f"Total amount is Npr.{sum}")
  if sum>=5000:
    print(f"You got 15% discount({(15*sum)/100}) out of Npr.{sum}")
    return f"Your Bill Amount is {sum-(15*sum)/100}"
  elif 3000<=sum<5000:
    print(f"You got 10% discount({(10*sum)/100}) out of Npr.{sum}")
    return f"Your Bill Amount is {sum-(10*sum)/100}"
  elif 1000<=sum<3000:
    print(f"You got 5% discount({(5*sum)/100}) out of Npr.{sum}")
    return f"Your Payable Bill Amount is Npr.{sum-(5*sum)/100}"
  else:
    print("Sorry sir/maam, No discount for you.")
shopping_cart()
# Out:
# Enter a 1 product price: Npr.400
# [400.0]
# Enter a 2 product price: Npr.350
# [400.0, 350.0]
# Enter a 3 product price: Npr.600
# [400.0, 350.0, 600.0]
# Enter a 4 product price: Npr.230
# [400.0, 350.0, 600.0, 230.0]
# Enter a 5 product price: Npr.75
# [400.0, 350.0, 600.0, 230.0, 75.0]
# Summary your product price list is: [400.0, 350.0, 600.0, 230.0, 75.0]
# Total amount is Npr.1655.0
# You got 5% discount(82.75) out of Npr.1655.0
# 'Your Payable Bill Amount is Npr.1572.25'
