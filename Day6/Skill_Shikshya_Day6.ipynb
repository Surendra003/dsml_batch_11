# %%
#jeson format is dictionary
#id = keys
#101 = values
#mapping type is distionary
#json parse maintain format

data ={
    "id" : "Jane Doe",
    "is_active" : True,
    "roles" : ["Admin", "Editor"],
    "contact" : {
        "email" : "jane@gmail.com",
        "phone" : None
    }
}
print(data)
print(type(data))
# Out:
# {'id': 'Jane Doe', '\nis_active': True, 'roles': ['Admin', 'Editor'], 'contact': {'email': 'jane@gmail.com', 'phone': None}}
# <class 'dict'>

# %%
data=dict({"name":"Surendra","rollno:":23})
print(data)
students = dict({
    'student1':dict({"name":"surendra","age":24}),
    'student2' : dict({"name":"surendra","age":24})
      })
print(students)
# Out:
# {'name': 'Surendra', 'rollno:': 23}
# {'student1': {'name': 'surendra', 'age': 24}, 'student2': {'name': 'surendra', 'age': 24}}

# %%
#each item as pair
person = dict([("name","rita"),("country","nepal"), ("telephone",9808208)])
print(person)

#with mixed keys
sample_dict ={"name":"suren",10:"Mobile"}
print(sample_dict)

#value as a list
person = {"name":"Surnee","Telephone":[98003977,980836764,9737833]}
print(person)
# Out:
# {'name': 'rita', 'country': 'nepal', 'telephone': 9808208}
# {'name': 'suren', 10: 'Mobile'}
# {'name': 'Surnee', 'Telephone': [98003977, 980836764, 9737833]}

# %%
data_new = {
    'name' : 'suren',
    'age' : 24
}
print(data_new['name'])
data_new['name']='surendra'
print(data_new)
# Out:
# suren
# {'name': 'surendra', 'age': 24}

# %%
#all keys and values
data_new = {
    'name' : 'suren',
    'age' : 24
}
print(data_new.keys())
print(data_new.values())
print(data_new.items())
# Out:
# dict_keys(['name', 'age'])
# dict_values(['suren', 24])
# dict_items([('name', 'suren'), ('age', 24)])

# %%
#dictionary methods
data_new = {
    'name' : 'suren',
    'age' : 24,
    'num' : 9809787
}
data_new.pop('name')
print(data_new.popitem())
print(data_new)
#del data_new['num']
data_new.pop("phone","not found")
# Out:
# ('num', 9809787)
# {'age': 24}
# 'not found'

# %%
#update
dict1= {
    "name":"surendra"
}
dict2= {
    'rollno':37
}
dict1.update(dict2)
dict1
# Out:
# {'name': 'surendra', 'rollno': 37}

# %%
# *args, **kwargs
dict1= {"name":"surendra"}
dict2= {'rollno':37}
dict3 = {'age':45}
dict={**dict1,**dict2,**dict3}
dict
# Out:
# {'name': 'surendra', 'rollno': 37, 'age': 45}

# %%
#dictionary merge
dict1= {"name":"surendra"}
dict2= {'rollno':37}
dict1|dict2
#sorted
students = {"b":2,"a":1,"c":3}
result = sorted(students)
print(result)

# %%
#class task
student = {"name":("Surendra","Hemraj"),
           "age":(23,45),
           "faculty":("Science","Math")
           }
print(student)
student["age"]=30
student.update({"age": 27, "city": "Kathmandu"})
