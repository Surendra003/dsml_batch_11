# %%
#doc string
def sum(a,b):
  '''adding two numbers
  '''
  return a+b
print(sum.__doc__)
help(sum)
# Out:
# adding two numbers
#
# Help on function sum in module __main__:
#
# sum(a, b)
#     adding two numbers

# %%
def calculate_area(length, width):
  '''to calculate the area'''
  return length*width
print(calculate_area.__doc__)
# Out:
# to calculate the area

# %%
def show(*args):
  return args
print(*show("welcome",'to',"skillshikshya"))
# Out:
# welcome to skillshikshya

# %%
data = ["skill"]
print(*data)
# Out:
# skill

# %%
def show(**kargs):
  return kargs
print(show(name="Surendra", age=25))
# Out:
# {'name': 'Surendra', 'age': 25}

# %%
def data3(n,m, *args, **kwargs):
  print(n)
  print(m)
  print(args)
  print(kwargs)
data3(2,3,4,5,6,s=3,o=4)
# Out:
# 2
# 3
# (4, 5, 6)
# {'s': 3, 'o': 4}

# %%
def pizza_order(order,*customerorder,**customerdetails):
  print(order)
  print(customerorder)
  print(customerdetails)

pizza_order(3,"pizza1","pizza2","pizza3",name="Surendra", age=24,location="Koteshwor")
# Out:
# 3
# ('pizza1', 'pizza2', 'pizza3')
# {'name': 'Surendra', 'age': 24, 'location': 'Koteshwor'}

# %%
def pizza_order(order,*customerorder,**customerdetails):
  print(order)
  print("Ingridients:")
  for i in customerorder:
    print("-",i)
  for i in customerdetails.items():
    print(i)
pizza_order(3,"pizza1","pizza2","pizza3",name="Surendra", age=24,location="Koteshwor")
# Out:
# 3
# Ingridients:
# - pizza1
# - pizza2
# - pizza3
# ('name', 'Surendra')
# ('age', 24)
# ('location', 'Koteshwor')
