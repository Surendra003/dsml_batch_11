# %%
number = 122
b=float(number)
print(type(number))
# Out:
# <class 'int'>

# %% [markdown]
# float = 1.34
# type(float)

# %%
complex = 3+3j
type(complex)
# Out:
# complex

# %%
a=122
b=float(a)
type(b)
# Out:
# float

# %%
#operation
a=12
b=7
c=a-b
d=a+b
e=a*b
f=a/d
g=a%b
h=a//b  #floor
print(f"sub: {c}, add={d}, mul={e}, div={f}, mudulus={g}, floor={h}")
# Out:
# sub: 5, add=19, mul=84, div=0.631578947368421, mudulus=5, floor=1

# %%
#comparision or condition operation
a=30
b=29
c=a<b
print(c)
d=a<=b
print(d)
e=a>b
print(e)
f=a>=b
print(f)
g=a!=b
print(g)
print(a==b)
# Out:
# False
# False
# True
# True
# True
# False

# %%
import math
math.floor(44.9)
math.ceil(44.9)
math.gcd(3,6,9,12)
a=round(22.5)
print(a)
user=640
capacity=128
result=min(user,capacity)
print(result)
# Out:
# 22
# 128

# %%
#string
text1="It's a sunny day."
text2='He said "hello".'
print(text1)
print(text2)
#concatinate
print(text1+" "+text2)
print(text1,text2)
# Out:
# It's a sunny day.
# He said "hello".
# It's a sunny day. He said "hello".
# It's a sunny day. He said "hello".

# %%
#print multiple times
print(text1*3)
# Out:
# It's a sunny day.It's a sunny day.It's a sunny day.

# %%
#indexing
data= "Pythonhacker"
data[3]
# Out:
# 'h'

# %%
#slicing
#daata[start:end:step]
data[1:3]
data[1:5:2]
# Out:
# 'yh'

# %%
dat="Hello Python"
dat[1:-1]
dat[1:-1:2]
# Out:
# 'el yh'

# %%
#count length
len(dat)
# Out:
# 12

# %%
#replace argument
data3="Iam a Boy"
print(data3.upper())
print(data3.lower())
print(data3.strip())
print(data3.split())
print(data3.join("hello"))
print(data3.replace("Boy","Girl"))
# Out:
# IAM A BOY
# iam a boy
# Iam a Boy
# ['Iam', 'a', 'Boy']
# hIam a BoyeIam a BoylIam a BoylIam a Boyo
# Iam a Girl

# %%
data4=" hello hari is good boy "
print(data4.strip())  #remove space of first and last
print(data4.join(" "))
# Out:
# hello hari is good boy
